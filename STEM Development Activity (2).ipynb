# %%
print('Welcome to AskPython Quiz')
answer=input('Are you ready to play the Quiz? (yes or no) :')
Score=0
total_questions=10
 
if answer.lower()=='yes':
    answer=input('Question 1: How many billion nerve cells does the humain brain have? a) 25 b) 50 c) 100 d) 125')
    if answer.lower()=='c':
        Score += 1
        print('Correct!')
    else:
        print('Wrong Answer')
    

score = "Score = "

print (score + str(Score))

answer=input('Question 2: How many bones are in the human foot? a) 16 b) 18 c) 24 d) 26')
if answer.lower()=='d':
        Score += 1
        print('Correct!')
else:
        print('Wrong Answer')
    
print (score + str(Score))


answer=input('Question 3: There is enough DNA in the human body to stretch to Pluto and back how many times? a) 3 b) 5 c) 7 d) 9')
if answer.lower()=='c':
        Score += 1
        print('Correct!')
else:
        print('Wrong Answer')
    
print (score + str(Score))


answer=input('Question 4: How many brains does an octopus have? a) 5 b) 9 c) 12 d) 13')
if answer.lower()=='b':
        Score += 1
        print('Correct!')
else:
        print('Wrong Answer')
    
print (score + str(Score))


answer=input('Question 5: How many minutes does it take for light from the Sun to hit Earth? a) 8 b) 9 c) 10 d) 11')
if answer.lower()=='a':
        Score += 1
        print('Correct!')
else:
        print('Wrong Answer')
    
print (score + str(Score))

print ("Great job! You're half way done... keep it up!")


answer=input('Question 6: How many liters of saliva does a human mouth produce each day on average?  a) .25 b) .5 c) .75 d) 1')
if answer.lower()=='d':
        Score += 1
        print('Correct!')
else:
        print('Wrong Answer')
    
print (score + str(Score))


answer=input('Question 7: How many degrees can owls rotate their heads without moving their body? a) 90 b) 180 c) 270 d) 360')
if answer.lower()=='c':
        Score += 1
        print('Correct!')
else:
        print('Wrong Answer')
    
print (score + str(Score))



answer=input('Question 8: How many natural enemies do polar bears have? a) 0 b) 3 c) 10 d) 12')
if answer.lower()=='a':
        Score += 1
        print('Correct!')
else:
        print('Wrong Answer')
    
print (score + str(Score))


answer=input('Question 9: When did Neil Armstrong walk on the moon? a) 1969 b) 1970 c) 1971 d) 1972')
if answer.lower()=='a':
        Score += 1
        print('Correct!')
else:
        print('Wrong Answer')
    
print (score + str(Score))


print ("Last question...")

answer=input('Are you ready? (yes or no) :')


if answer.lower()=='yes':
    answer=input('Question 10: If spread out, the total surface area of adult lungs can be up to how many square meters long? a) 25 b) 50 c) 75 d) 100')
    if answer.lower()=='c':
        Score += 1
        print('Correct!')
    else:
        print('Wrong Answer')


thanks = "Thank you for playing! You did a GREAT job! Your score was "

total = "/10."
      
print (thanks + str(Score) + total)


print('Keep learning cool science facts!')        
        

print ("Here are some cool URLs I got these questions from: https://www.science-sparks.com/fun-science-facts/, https://flintobox.com/blog/child-development/science-facts-kids")
# Out:
# Welcome to AskPython Quiz
